# %%
from sklearn.datasets import load_diabetes
from sklearn.metrics import mean_squared_error
import numpy as np
diabetes = load_diabetes()
diabetes
# Out:
# {'data': array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#           0.01990749, -0.01764613],
#         [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#          -0.06833155, -0.09220405],
#         [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#           0.00286131, -0.02593034],
#         ...,
#         [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#          -0.04688253,  0.01549073],
#         [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#           0.04452873, -0.02593034],
#         [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#          -0.00422151,  0.00306441]]),
#  'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#          69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#          68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#          87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
# ...

# %%
import pandas as pd
pd.DataFrame(diabetes.data, columns=("age", "sex", "bmi", "map", "s1", "s2", "s3", "s4", "s5", "s6"))
# Out:
#           age       sex       bmi       map        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019907 -0.017646
# ...

# %%
from sklearn.model_selection import train_test_split
train_X, test_X, train_y, test_y = train_test_split(diabetes.data, diabetes.target, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(train_X, train_y)
print(model.score(test_X, test_y))
print(model.predict(test_X))
# Out:
# 0.4849058889476755
# [137.94908878 182.533354   129.85295373 292.5630923  124.86788221
#   89.73883143 255.95872903 177.64545905  87.8884795  107.93961905
#   93.26357149 171.11939483  56.06305218 207.22146277  99.78918734
#  131.7128101  215.86378125 252.18591603 201.56577486 220.38870357
#  204.35745939  88.9068622   68.52958146 190.02378425 153.91270751
#  164.02719031 192.83227597 187.16765226  46.60570802 109.3112624
#  175.04965912  87.8076198  130.37646375 186.56325253 172.4733248
#  188.61448165 124.07175323 119.16132637 147.74400127  59.27254049
#   70.90046253 109.30036497 170.97191153 156.56943489 168.68664924
#   61.5457612   71.19039454 111.94779801  54.32009551 165.81267886
#  152.78043565  63.80587155 110.07651605 108.64317139 179.16381014
#  156.79651896  93.29011121 212.91986757 119.28417849  70.70890653
#  186.678156   205.65720098 140.02890626 106.54792751 131.56053828
#  204.1777152  173.28530628 168.65451177 123.58356159 145.48705122
# ...

# %%
print(model.score(test_X, test_y))
# Out:
# 0.4849058889476755

# %%
print(model.score(train_X, train_y))
# Out:
# 0.519034189167905

# %%
pred_y=model.predict(test_X)

# %%
(pred_y-test_y)**2
# Out:
# array([6.56925021e+03, 1.26637558e+04, 5.20519629e+03, 3.91414052e+03,
#        1.92318157e+02, 3.29341862e+01, 1.94846116e+02, 8.90277940e+03,
#        3.73506828e+01, 1.42554503e+02, 5.42326951e-01, 6.54167229e+03,
#        1.84358149e+03, 8.06018575e+03, 1.23980133e+03, 4.18774779e+03,
#        6.26254112e+03, 1.39572580e+02, 9.96398143e+02, 2.98239370e+03,
#        1.11603464e+04, 6.20351785e+02, 3.53673068e+03, 1.76200269e+03,
#        6.20642996e+02, 2.11850225e+03, 4.92350950e+03, 1.21369116e+04,
#        1.94405013e+00, 5.34193388e+00, 1.22847860e+03, 6.34656020e+02,
#        1.63025883e+03, 5.09100365e+02, 5.66508396e+01, 1.97007424e+03,
#        6.73577268e+03, 1.23631887e+03, 5.88353474e+02, 1.38939544e+01,
#        5.24431184e+02, 1.69094906e+00, 2.24158135e+02, 1.30657819e+02,
#        6.19158877e+03, 9.11215568e+01, 1.65919145e+04, 6.22392626e+02,
#        1.27305558e+03, 8.49850218e+03, 2.81583021e+02, 8.87253384e+03,
# ...

# %%
mse = mean_squared_error(test_y, pred_y)
print(np.sqrt(mse))
# Out:
# 53.369566710321955

# %%
mse = np.mean((test_y-pred_y)**2)
print(mse)
# Out:
# 2848.3106508475057

# %%
mae = np.mean(np.abs(test_y-pred_y))
print(mae)
# Out:
# 41.54850685988061

# %%
pred_y=model.predict(train_X)
mse = np.mean((train_y-pred_y)**2)
print(mse)
mae = np.mean(np.abs(train_y-pred_y))
print(mae)
# Out:
# 2907.2577640101085
# 44.054803735772055
