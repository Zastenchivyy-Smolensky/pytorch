# %%
# !pip3 install scikit_learn
# Out:
# Requirement already satisfied: scikit_learn in c:\users\user\anaconda3\lib\site-packages (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from scikit_learn) (3.1.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\user\anaconda3\lib\site-packages (from scikit_learn) (1.22.3)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\user\anaconda3\lib\site-packages (from scikit_learn) (1.6.0)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from scikit_learn) (1.1.0)

# %%
from sklearn.datasets import load_iris
iris=load_iris()

# %%
print(iris.DESCR)
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
#     ============== ==== ==== ======= ===== ====================
#
#     :Missing Attribute Values: None
#     :Class Distribution: 33.3% for each of 3 classes.
#     :Creator: R.A. Fisher
#     :Donor: Michael Marshall (MARSHALL%PLU@io.arc.nasa.gov)
#     :Date: July, 1988
#
# The famous Iris database, first used by Sir R.A. Fisher. The dataset is taken
# from Fisher's paper. Note that it's the same as in R, but not as in the UCI
# Machine Learning Repository, which has two wrong data points.
#
# This is perhaps the best known database to be found in the
# pattern recognition literature.  Fisher's paper is a classic in the field and
# is referenced frequently to this day.  (See Duda & Hart, for example.)  The
# data set contains 3 classes of 50 instances each, where each class refers to a
# type of iris plant.  One class is linearly separable from the other 2; the
# latter are NOT linearly separable from each other.
#
# .. topic:: References
#
#    - Fisher, R.A. "The use of multiple measurements in taxonomic problems"
#      Annual Eugenics, 7, Part II, 179-188 (1936); also in "Contributions to
#      Mathematical Statistics" (John Wiley, NY, 1950).
#    - Duda, R.O., & Hart, P.E. (1973) Pattern Classification and Scene Analysis.
#      (Q327.D83) John Wiley & Sons.  ISBN 0-471-22361-1.  See page 218.
#    - Dasarathy, B.V. (1980) "Nosing Around the Neighborhood: A New System
#      Structure and Classification Rule for Recognition in Partially Exposed
#      Environments".  IEEE Transactions on Pattern Analysis and Machine
#      Intelligence, Vol. PAMI-2, No. 1, 67-71.
#    - Gates, G.W. (1972) "The Reduced Nearest Neighbor Rule".  IEEE Transactions
#      on Information Theory, May 1972, 431-433.
#    - See also: 1988 MLC Proceedings, 54-64.  Cheeseman et al"s AUTOCLASS II
#      conceptual clustering system finds 3 classes in the data.
#    - Many, many more ...

# %%
import pandas as pd
df=pd.DataFrame(iris.data, columns=iris.feature_names)
print(df.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df["Variety"] = iris.target
df.loc[df["Variety"] == 0, "Variety"] == "setosa"
df.loc[df["Variety"] == 1, "Variety"] == "versicolor"
df.loc[df["Variety"] == 2, "Variety"] == "virginica"
print(df.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    Variety
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
print(df.describe())
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)     Variety
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(df, hue="Variety")
plt.show()

# %%
#ここから
#ディープラーニング
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# %%
import torch 
from torch.utils.data import TensorDataset, DataLoader
from torch import nn
import torch.nn.functional as F
from torch import optim

# %%
iris = load_iris()
data = iris.data
label = iris.target

# %%
train_data, test_data, train_label, test_label = train_test_split(
            data, label, test_size=0.2)
print("train_data size: {}".format(len(train_data)))
print("test_data size: {}".format(len(test_data)))
print("train_label size: {}".format(len(train_label)))
print("test_label size: {}".format(len(test_label)))
# Out:
# train_data size: 120
# test_data size: 30
# train_label size: 120
# test_label size: 30

# %%
train_x = torch.Tensor(train_data)
test_x = torch.Tensor(test_data)
train_y = torch.LongTensor(train_label)
test_y = torch.LongTensor(test_label)

# %%
train_dataset = TensorDataset(train_x, train_y)
test_dataset = TensorDataset(test_x, test_y)

# %%
train_batch = DataLoader(
    dataset=train_dataset,
    batch_size=5,
    shuffle=True,
    num_workers=2)
test_batch = DataLoader(
    dataset=test_dataset,
    batch_size=5,
    shuffle=False,
    num_workers=2)
for data, label in train_batch:
    print("batch data size: {}".format(data.size()))
    print("batch label size: {}".format(label.size()))
    break
# Out:
# batch data size: torch.Size([5, 4])
# batch label size: torch.Size([5])

# %%
for data, label in train_batch:
    print("batch data size: {}".format(data.size()))
    print("batch label size: {}".format(label.size()))
    break
# Out:
# batch data size: torch.Size([5, 4])
# batch label size: torch.Size([5])

# %%
class Net(nn.Module):
    def __init__(self, D_in, H ,D_out):
        super(Net, self).__init__()
        self.linear1 = torch.nn.Linear(D_in,H)
        self.linear2 = torch.nn.Linear(H,D_out)
    def forward(self, x):
        x = F.relu(self.linear1(x))
        x = self.linear2(x)
        return x

# %%
D_in=4
H=100
D_out=3
epoch=100

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
net = Net(D_in,H,D_out).to(device)
print("Device: {}".format(device))
# Out:
# Device: cpu

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters())

# %%
train_loss_list = []
train_accuracy_list = []
test_loss_list = []
test_accuracy_list = []

for i in range(epoch):
    print("--------------------------------")
    print("Epoch: {}/{}".format(i+1, epoch))
    train_loss = 0
    train_accuracy = 0
    test_loss = 0
    test_accuracy = 0
    
    net.train()
    for data, label in train_batch:
        data = data.to(device)
        label = label.to(device)
        optimizer.zero_grad()
        y_pred_prod = net(data)
        loss = criterion(y_pred_prod, label)
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item()
        y_pred_label = torch.max(y_pred_prod,1)[1]
        train_accuracy += torch.sum(y_pred_label == label).item()/len(label)
    batch_train_loss = train_loss/len(train_batch)
    batch_train_accuracy = train_accuracy / len(train_batch)
    
    net.eval()
    with torch.no_grad():
        for data, label in test_batch:
            data = data.to(device)
            label = label.to(device)
            optimizer.zero_grad()
            y_pred_prod = net(data)
            loss = criterion(y_pred_prod, label)
            test_loss += loss.item()
            y_pred_label = torch.max(y_pred_prod, 1)[1]
            test_accuracy += torch.sum(y_pred_label == label).item()/len(label)
    batch_test_loss = test_loss/len(test_batch)
    batch_test_accuracy = test_accuracy/len(test_batch)
    
    print("Train_loss: {:.4f} Train_Accuracy: {:.4f}".format(
    batch_train_loss, batch_train_accuracy))
    
    print("Test_loss: {:.4f} Test_Accuracy: {:.4f}".format(
    batch_test_loss, batch_test_accuracy))
        
    train_loss_list.append(batch_train_loss)
    train_accuracy_list.append(batch_train_accuracy)
    test_loss_list.append(batch_test_loss)
    test_accuracy_list.append(batch_test_accuracy)
# Out:
# --------------------------------
# Epoch: 1/100
# Train_loss: 0.9537 Train_Accuracy: 0.5583
# Test_loss: 0.8073 Test_Accuracy: 0.9000
# --------------------------------
# Epoch: 2/100
# Train_loss: 0.7269 Train_Accuracy: 0.9417
# Test_loss: 0.6208 Test_Accuracy: 0.9333
# --------------------------------
# Epoch: 3/100
# Train_loss: 0.6053 Train_Accuracy: 0.8250
# Test_loss: 0.5221 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 4/100
# Train_loss: 0.5301 Train_Accuracy: 0.8917
# Test_loss: 0.4479 Test_Accuracy: 0.9000
# --------------------------------
# Epoch: 5/100
# Train_loss: 0.4770 Train_Accuracy: 0.9167
# Test_loss: 0.4173 Test_Accuracy: 1.0000
# --------------------------------
# Epoch: 6/100
# Train_loss: 0.4411 Train_Accuracy: 0.9250
# Test_loss: 0.3663 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 7/100
# Train_loss: 0.4085 Train_Accuracy: 0.9250
# Test_loss: 0.3990 Test_Accuracy: 0.9000
# --------------------------------
# Epoch: 8/100
# Train_loss: 0.4020 Train_Accuracy: 0.9083
# Test_loss: 0.3620 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 9/100
# Train_loss: 0.3588 Train_Accuracy: 0.9417
# Test_loss: 0.2956 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 10/100
# Train_loss: 0.3647 Train_Accuracy: 0.8667
# Test_loss: 0.3074 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 11/100
# Train_loss: 0.3226 Train_Accuracy: 0.9750
# Test_loss: 0.2672 Test_Accuracy: 1.0000
# --------------------------------
# Epoch: 12/100
# Train_loss: 0.3040 Train_Accuracy: 0.9333
# Test_loss: 0.3533 Test_Accuracy: 0.8667
# --------------------------------
# Epoch: 13/100
# Train_loss: 0.2938 Train_Accuracy: 0.9667
# Test_loss: 0.2471 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 14/100
# Train_loss: 0.2774 Train_Accuracy: 0.9833
# Test_loss: 0.2184 Test_Accuracy: 1.0000
# --------------------------------
# Epoch: 15/100
# Train_loss: 0.2597 Train_Accuracy: 0.9583
# Test_loss: 0.2199 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 16/100
# Train_loss: 0.2499 Train_Accuracy: 0.9750
# Test_loss: 0.1905 Test_Accuracy: 1.0000
# --------------------------------
# Epoch: 17/100
# Train_loss: 0.2320 Train_Accuracy: 0.9500
# Test_loss: 0.2218 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 18/100
# Train_loss: 0.2316 Train_Accuracy: 0.9583
# Test_loss: 0.1796 Test_Accuracy: 1.0000
# --------------------------------
# Epoch: 19/100
# Train_loss: 0.2139 Train_Accuracy: 0.9583
# Test_loss: 0.1737 Test_Accuracy: 1.0000
# --------------------------------
# Epoch: 20/100
# Train_loss: 0.2095 Train_Accuracy: 0.9583
# Test_loss: 0.2176 Test_Accuracy: 0.9000
# --------------------------------
# Epoch: 21/100
# Train_loss: 0.2040 Train_Accuracy: 0.9667
# Test_loss: 0.1445 Test_Accuracy: 1.0000
# --------------------------------
# Epoch: 22/100
# Train_loss: 0.1898 Train_Accuracy: 0.9667
# Test_loss: 0.1575 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 23/100
# Train_loss: 0.1881 Train_Accuracy: 0.9583
# Test_loss: 0.1918 Test_Accuracy: 0.9000
# --------------------------------
# Epoch: 24/100
# Train_loss: 0.1794 Train_Accuracy: 0.9583
# Test_loss: 0.1452 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 25/100
# Train_loss: 0.1713 Train_Accuracy: 0.9750
# Test_loss: 0.1273 Test_Accuracy: 1.0000
# --------------------------------
# Epoch: 26/100
# Train_loss: 0.1626 Train_Accuracy: 0.9583
# Test_loss: 0.1217 Test_Accuracy: 1.0000
# --------------------------------
# Epoch: 27/100
# Train_loss: 0.1556 Train_Accuracy: 0.9750
# Test_loss: 0.1289 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 28/100
# Train_loss: 0.1573 Train_Accuracy: 0.9750
# Test_loss: 0.1109 Test_Accuracy: 1.0000
# --------------------------------
# Epoch: 29/100
# Train_loss: 0.1474 Train_Accuracy: 0.9667
# Test_loss: 0.1130 Test_Accuracy: 1.0000
# --------------------------------
# Epoch: 30/100
# Train_loss: 0.1441 Train_Accuracy: 0.9667
# Test_loss: 0.1107 Test_Accuracy: 1.0000
# --------------------------------
# Epoch: 31/100
# Train_loss: 0.1392 Train_Accuracy: 0.9667
# Test_loss: 0.1127 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 32/100
# Train_loss: 0.1424 Train_Accuracy: 0.9667
# Test_loss: 0.1200 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 33/100
# Train_loss: 0.1371 Train_Accuracy: 0.9667
# Test_loss: 0.0944 Test_Accuracy: 1.0000
# --------------------------------
# Epoch: 34/100
# Train_loss: 0.1252 Train_Accuracy: 0.9750
# Test_loss: 0.1208 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 35/100
# Train_loss: 0.1261 Train_Accuracy: 0.9750
# Test_loss: 0.1022 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 36/100
# Train_loss: 0.1213 Train_Accuracy: 0.9750
# Test_loss: 0.0912 Test_Accuracy: 1.0000
# --------------------------------
# Epoch: 37/100
# Train_loss: 0.1247 Train_Accuracy: 0.9667
# Test_loss: 0.1028 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 38/100
# Train_loss: 0.1188 Train_Accuracy: 0.9750
# Test_loss: 0.0982 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 39/100
# Train_loss: 0.1155 Train_Accuracy: 0.9667
# Test_loss: 0.0923 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 40/100
# Train_loss: 0.1144 Train_Accuracy: 0.9667
# Test_loss: 0.0818 Test_Accuracy: 1.0000
# --------------------------------
# Epoch: 41/100
# Train_loss: 0.1194 Train_Accuracy: 0.9750
# Test_loss: 0.0722 Test_Accuracy: 1.0000
# --------------------------------
# Epoch: 42/100
# Train_loss: 0.1354 Train_Accuracy: 0.9583
# Test_loss: 0.0932 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 43/100
# Train_loss: 0.1158 Train_Accuracy: 0.9583
# Test_loss: 0.1428 Test_Accuracy: 0.9000
# --------------------------------
# Epoch: 44/100
# Train_loss: 0.1135 Train_Accuracy: 0.9750
# Test_loss: 0.0912 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 45/100
# Train_loss: 0.1033 Train_Accuracy: 0.9667
# Test_loss: 0.0727 Test_Accuracy: 1.0000
# --------------------------------
# Epoch: 46/100
# Train_loss: 0.1072 Train_Accuracy: 0.9583
# Test_loss: 0.0877 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 47/100
# Train_loss: 0.1062 Train_Accuracy: 0.9750
# Test_loss: 0.0859 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 48/100
# Train_loss: 0.1029 Train_Accuracy: 0.9667
# Test_loss: 0.0745 Test_Accuracy: 1.0000
# --------------------------------
# Epoch: 49/100
# Train_loss: 0.1020 Train_Accuracy: 0.9750
# Test_loss: 0.0751 Test_Accuracy: 1.0000
# --------------------------------
# Epoch: 50/100
# Train_loss: 0.1058 Train_Accuracy: 0.9750
# Test_loss: 0.0727 Test_Accuracy: 1.0000
# --------------------------------
# Epoch: 51/100
# Train_loss: 0.1014 Train_Accuracy: 0.9750
# Test_loss: 0.0933 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 52/100
# Train_loss: 0.1026 Train_Accuracy: 0.9750
# Test_loss: 0.1059 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 53/100
# Train_loss: 0.1039 Train_Accuracy: 0.9667
# Test_loss: 0.1124 Test_Accuracy: 0.9333
# --------------------------------
# Epoch: 54/100
# Train_loss: 0.0951 Train_Accuracy: 0.9750
# Test_loss: 0.0816 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 55/100
# Train_loss: 0.1002 Train_Accuracy: 0.9583
# Test_loss: 0.0715 Test_Accuracy: 1.0000
# --------------------------------
# Epoch: 56/100
# Train_loss: 0.0926 Train_Accuracy: 0.9750
# Test_loss: 0.0845 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 57/100
# Train_loss: 0.0949 Train_Accuracy: 0.9667
# Test_loss: 0.0693 Test_Accuracy: 1.0000
# --------------------------------
# Epoch: 58/100
# Train_loss: 0.0936 Train_Accuracy: 0.9750
# Test_loss: 0.0697 Test_Accuracy: 1.0000
# --------------------------------
# Epoch: 59/100
# Train_loss: 0.1025 Train_Accuracy: 0.9667
# Test_loss: 0.0900 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 60/100
# Train_loss: 0.0935 Train_Accuracy: 0.9667
# Test_loss: 0.1003 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 61/100
# Train_loss: 0.0939 Train_Accuracy: 0.9667
# Test_loss: 0.0803 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 62/100
# Train_loss: 0.0851 Train_Accuracy: 0.9750
# Test_loss: 0.0656 Test_Accuracy: 1.0000
# --------------------------------
# Epoch: 63/100
# Train_loss: 0.0952 Train_Accuracy: 0.9667
# Test_loss: 0.0976 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 64/100
# Train_loss: 0.0892 Train_Accuracy: 0.9750
# Test_loss: 0.0715 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 65/100
# Train_loss: 0.0824 Train_Accuracy: 0.9750
# Test_loss: 0.0646 Test_Accuracy: 1.0000
# --------------------------------
# Epoch: 66/100
# Train_loss: 0.0910 Train_Accuracy: 0.9750
# Test_loss: 0.0518 Test_Accuracy: 1.0000
# --------------------------------
# Epoch: 67/100
# Train_loss: 0.0957 Train_Accuracy: 0.9667
# Test_loss: 0.1093 Test_Accuracy: 0.9000
# --------------------------------
# Epoch: 68/100
# Train_loss: 0.0935 Train_Accuracy: 0.9667
# Test_loss: 0.0851 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 69/100
# Train_loss: 0.0868 Train_Accuracy: 0.9750
# Test_loss: 0.0708 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 70/100
# Train_loss: 0.0905 Train_Accuracy: 0.9667
# Test_loss: 0.1001 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 71/100
# Train_loss: 0.0932 Train_Accuracy: 0.9750
# Test_loss: 0.0832 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 72/100
# Train_loss: 0.0859 Train_Accuracy: 0.9667
# Test_loss: 0.0606 Test_Accuracy: 1.0000
# --------------------------------
# Epoch: 73/100
# Train_loss: 0.0818 Train_Accuracy: 0.9667
# Test_loss: 0.0550 Test_Accuracy: 1.0000
# --------------------------------
# Epoch: 74/100
# Train_loss: 0.0847 Train_Accuracy: 0.9667
# Test_loss: 0.0642 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 75/100
# Train_loss: 0.0825 Train_Accuracy: 0.9583
# Test_loss: 0.0794 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 76/100
# Train_loss: 0.0784 Train_Accuracy: 0.9833
# Test_loss: 0.0445 Test_Accuracy: 1.0000
# --------------------------------
# Epoch: 77/100
# Train_loss: 0.0973 Train_Accuracy: 0.9667
# Test_loss: 0.0994 Test_Accuracy: 0.9333
# --------------------------------
# Epoch: 78/100
# Train_loss: 0.0810 Train_Accuracy: 0.9833
# Test_loss: 0.0729 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 79/100
# Train_loss: 0.0796 Train_Accuracy: 0.9667
# Test_loss: 0.0482 Test_Accuracy: 1.0000
# --------------------------------
# Epoch: 80/100
# Train_loss: 0.0781 Train_Accuracy: 0.9750
# Test_loss: 0.0578 Test_Accuracy: 1.0000
# --------------------------------
# Epoch: 81/100
# Train_loss: 0.0797 Train_Accuracy: 0.9667
# Test_loss: 0.0833 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 82/100
# Train_loss: 0.0880 Train_Accuracy: 0.9667
# Test_loss: 0.0932 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 83/100
# Train_loss: 0.0793 Train_Accuracy: 0.9583
# Test_loss: 0.0487 Test_Accuracy: 1.0000
# --------------------------------
# Epoch: 84/100
# Train_loss: 0.0808 Train_Accuracy: 0.9667
# Test_loss: 0.0503 Test_Accuracy: 1.0000
# --------------------------------
# Epoch: 85/100
# Train_loss: 0.0745 Train_Accuracy: 0.9667
# Test_loss: 0.0954 Test_Accuracy: 0.9333
# --------------------------------
# Epoch: 86/100
# Train_loss: 0.0770 Train_Accuracy: 0.9750
# Test_loss: 0.0645 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 87/100
# Train_loss: 0.0741 Train_Accuracy: 0.9750
# Test_loss: 0.0609 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 88/100
# Train_loss: 0.0721 Train_Accuracy: 0.9833
# Test_loss: 0.0530 Test_Accuracy: 1.0000
# --------------------------------
# Epoch: 89/100
# Train_loss: 0.0823 Train_Accuracy: 0.9833
# Test_loss: 0.1303 Test_Accuracy: 0.9000
# --------------------------------
# Epoch: 90/100
# Train_loss: 0.0784 Train_Accuracy: 0.9750
# Test_loss: 0.0604 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 91/100
# Train_loss: 0.0748 Train_Accuracy: 0.9667
# Test_loss: 0.0816 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 92/100
# Train_loss: 0.0733 Train_Accuracy: 0.9750
# Test_loss: 0.0719 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 93/100
# Train_loss: 0.0726 Train_Accuracy: 0.9750
# Test_loss: 0.0620 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 94/100
# Train_loss: 0.0766 Train_Accuracy: 0.9750
# Test_loss: 0.1034 Test_Accuracy: 0.9000
# --------------------------------
# Epoch: 95/100
# Train_loss: 0.0739 Train_Accuracy: 0.9750
# Test_loss: 0.0634 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 96/100
# Train_loss: 0.0716 Train_Accuracy: 0.9750
# Test_loss: 0.0621 Test_Accuracy: 0.9667
# --------------------------------
# Epoch: 97/100
# Train_loss: 0.0766 Train_Accuracy: 0.9750
# Test_loss: 0.0390 Test_Accuracy: 1.0000
# --------------------------------
# Epoch: 98/100
# Train_loss: 0.0777 Train_Accuracy: 0.9833
# Test_loss: 0.0936 Test_Accuracy: 0.9333
# --------------------------------
# Epoch: 99/100
# Train_loss: 0.0720 Train_Accuracy: 0.9833
# Test_loss: 0.0344 Test_Accuracy: 1.0000
# --------------------------------
# Epoch: 100/100
# Train_loss: 0.0723 Train_Accuracy: 0.9750
# Test_loss: 0.0754 Test_Accuracy: 0.9667

# %%
plt.figure()
plt.title("Train and Test LOSS")
plt.xlabel("Epoch")
plt.ylabel("LOSS")
plt.plot(range(1, epoch+1), train_loss_list, color="blue",
        linestyle="-", label="Train_loss")
plt.plot(range(1, epoch+1), test_loss_list, color="red",
        linestyle="--", label="Test_loss")
plt.legend()

plt.figure()
plt.title("Train and Test LOSS")
plt.xlabel("Epoch")
plt.ylabel("LOSS")
plt.plot(range(1, epoch+1), train_accuracy_list, color="blue",
        linestyle="-", label="Train_Accuracy")
plt.plot(range(1, epoch+1), test_accuracy_list, color="red",
        linestyle="--", label="Test_Accuracy")
plt.legend()
plt.show()

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.save(net.to(device).state_dict(),"3-2_iris_net.pth")

# %%
D_in = 4
H = 100
D_out = 3

net2 = Net(D_in, H, D_out).to(device)
net2.load_state_dict(torch.load("3-2_iris_net.pth", map_location=device))
# Out:
# <All keys matched successfully>

# %%
batch_test_accuracy = test_accuracy / len(test_batch)
print("Accuracy: {:.3f}".format(batch_test_accuracy))
# Out:
# Accuracy: 0.967

# %%
from sklearn.datasets import load_diabetes
diabetes = load_diabetes()

# %%
print(diabetes.DESCR)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
#   :Number of Instances: 442
#
#   :Number of Attributes: First 10 columns are numeric predictive values
#
#   :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
#   :Attribute Information:
#       - age     age in years
#       - sex
#       - bmi     body mass index
#       - bp      average blood pressure
#       - s1      tc, total serum cholesterol
#       - s2      ldl, low-density lipoproteins
#       - s3      hdl, high-density lipoproteins
#       - s4      tch, total cholesterol / HDL
#       - s5      ltg, possibly log of serum triglycerides level
#       - s6      glu, blood sugar level
#
# Note: Each of these 10 feature variables have been mean centered and scaled by the standard deviation times the square root of `n_samples` (i.e. the sum of squares of each column totals 1).
#
# Source URL:
# https://www4.stat.ncsu.edu/~boos/var.select/diabetes.html
#
# For more information see:
# Bradley Efron, Trevor Hastie, Iain Johnstone and Robert Tibshirani (2004) "Least Angle Regression," Annals of Statistics (with discussion), 407-499.
# (https://web.stanford.edu/~hastie/Papers/LARS/LeastAngle_2002.pdf)

# %%
import pandas as pd
df = pd.DataFrame(diabetes.data, columns=diabetes.feature_names)
df["target"] = diabetes.target

print(df.head())
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  target
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# 3  0.034309  0.022688 -0.009362   206.0
# 4 -0.002592 -0.031988 -0.046641   135.0

# %%
print(df.describe())
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -2.511817e-19  1.230790e-17 -2.245564e-16 -4.797570e-17 -1.381499e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123988e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665608e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670422e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564379e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320436e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   3.918434e-17 -5.777179e-18 -9.042540e-18  9.293722e-17  1.130318e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.156131e-01 -1.023071e-01 -7.639450e-02 -1.260971e-01 -1.377672e-01
# 25%   -3.035840e-02 -3.511716e-02 -3.949338e-02 -3.324559e-02 -3.317903e-02
# 50%   -3.819065e-03 -6.584468e-03 -2.592262e-03 -1.947171e-03 -1.077698e-03
# 75%    2.984439e-02  2.931150e-02  3.430886e-02  3.243232e-02  2.791705e-02
# max    1.987880e-01  1.811791e-01  1.852344e-01  1.335973e-01  1.356118e-01
#
#            target
# count  442.000000
# mean   152.133484
# std     77.093005
# min     25.000000
# 25%     87.000000
# 50%    140.500000
# 75%    211.500000
# max    346.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(df, x_vars=diabetes.feature_names, y_vars="target")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt 
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
import torch
from torch.utils.data import TensorDataset, DataLoader
from torch import nn
import torch.nn.functional as F
from torch import optim

# %%
diabetes = load_diabetes()
data = diabetes.data
label = diabetes.target.reshape(-1,1)
print("data size: {}".format(data.shape))
print("label size: {}".format(label.shape))
# Out:
# data size: (442, 10)
# label size: (442, 1)

# %%
train_data, test_data, train_label, test_label = train_test_split(
data, label, test_size=0.2)

print("train_data size: {}".format(len(train_data)))
print("test_data size: {}".format(len(test_data)))
print("train_label size: {}".format(len(train_label)))
print("test_label size: {}".format(len(test_label)))
# Out:
# train_data size: 353
# test_data size: 89
# train_label size: 353
# test_label size: 89

# %%
train_x = torch.Tensor(train_data)

# %%
test_x = torch.Tensor(test_data)
train_y = torch.Tensor(train_label)
test_y = torch.Tensor(test_label)

# %%
train_dataset = TensorDataset(train_x, train_y)
test_dataset = TensorDataset(test_x, test_y)

# %%
train_batch = DataLoader(
    dataset=train_dataset,
    batch_size=20,
    shuffle=True,
    num_workers=2)
test_batch = DataLoader(
    dataset=test_dataset,
    batch_size=20,
    shuffle=False,
    num_workers=2)
for data, label in train_batch:
    print("batch data size: {}".format(data.size()))
    print("batch label size: {}".format(label.size()))
    break
# Out:
# batch data size: torch.Size([20, 10])
# batch label size: torch.Size([20, 1])

# %%
class Net(nn.Module):
    def __init__(self, D_in, H ,D_out):
        super(Net, self).__init__()
        self.linear1 = nn.Linear(D_in,H)
        self.linear2 = nn.Linear(H,H)
        self.linear3 = nn.Linear(H,D_out)
        self.dropout = nn.Dropout(p=0.5)
    def forward(self, x):
        x = F.relu(self.linear1(x))
        x = F.relu(self.linear2(x))
        x = F.relu(self.linear2(x))
        x = self.dropout(x)
        x = self.linear3(x)
        return x

# %%
D_in=10
H = 200
D_out=1
epoch=100

# %%
#実行する環境を指定
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
net = Net(D_in,H,D_out).to(device)
print("Device: {}".format(device))#デバイスの確認
# Out:
# Device: cpu

# %%
criterion = nn.MSELoss()
criterion2 = nn.L1Loss()
optimizer = optim.Adam(net.parameters())

# %%
train_loss_list = []
train_mae_list = []
test_loss_list = []
test_mae_list = []

for i in range(epoch):
    print("--------------------------------")
    print("Epoch: {}/{}".format(i+1, epoch))
    train_loss = 0
    train_mae = 0
    test_loss = 0
    test_mae = 0
    
    net.train()
    for data, label in train_batch:
        data = data.to(device)
        label = label.to(device)
        optimizer.zero_grad()
        y_pred = net(data)
        loss = criterion(y_pred, label)
        mae = criterion2(y_pred, label)
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item()
        train_mae += mae.item()

    batch_train_loss = train_loss/len(train_batch)
    batch_train_mae = train_mae / len(train_batch)
    
    net.eval()
    with torch.no_grad():
        for data, label in test_batch:
            data = data.to(device)
            label = label.to(device)
            y_pred = net(data)
            loss = criterion(y_pred, label)
            mae = criterion2(y_pred, label)
            test_loss += loss.item()
            test_mae += mae.item()

    batch_test_loss = test_loss/len(test_batch)
    batch_test_mae = test_mae/len(test_batch)
    
    print("Train_loss: {:.4f} Train_Mae: {:.4f}".format(
    batch_train_loss, batch_train_mae))
    
    print("Test_loss: {:.4f} Test_Mae: {:.4f}".format(
    batch_test_loss, batch_test_mae))
        
    train_loss_list.append(batch_train_loss)
    test_loss_list.append(batch_test_loss)
    train_mae_list.append(batch_train_mae)
    test_mae_list.append(batch_test_mae)
# Out:
# --------------------------------
# Epoch: 1/100
# Train_loss: 29374.1369 Train_Mae: 153.0497
# Test_loss: 26373.8691 Test_Mae: 143.6133
# --------------------------------
# Epoch: 2/100
# Train_loss: 27387.5660 Train_Mae: 146.4365
# Test_loss: 21695.3523 Test_Mae: 126.4548
# --------------------------------
# Epoch: 3/100
# Train_loss: 17773.7351 Train_Mae: 108.9840
# Test_loss: 8563.7408 Test_Mae: 67.6821
# --------------------------------
# Epoch: 4/100
# Train_loss: 6088.1044 Train_Mae: 63.5754
# Test_loss: 5953.2432 Test_Mae: 68.7920
# --------------------------------
# Epoch: 5/100
# Train_loss: 5492.7621 Train_Mae: 63.0817
# Test_loss: 4490.4410 Test_Mae: 57.7710
# --------------------------------
# Epoch: 6/100
# Train_loss: 5145.3925 Train_Mae: 61.0597
# Test_loss: 4253.2504 Test_Mae: 56.9616
# --------------------------------
# Epoch: 7/100
# Train_loss: 4562.3620 Train_Mae: 57.9865
# Test_loss: 4088.3655 Test_Mae: 55.8028
# --------------------------------
# Epoch: 8/100
# Train_loss: 4580.9936 Train_Mae: 57.7169
# Test_loss: 3800.5971 Test_Mae: 53.0001
# --------------------------------
# Epoch: 9/100
# Train_loss: 4203.9917 Train_Mae: 55.0039
# Test_loss: 3656.8262 Test_Mae: 52.0407
# --------------------------------
# Epoch: 10/100
# Train_loss: 4269.2877 Train_Mae: 54.2928
# Test_loss: 3471.3040 Test_Mae: 50.3778
# --------------------------------
# Epoch: 11/100
# Train_loss: 3993.8080 Train_Mae: 53.1365
# Test_loss: 3415.1849 Test_Mae: 50.0395
# --------------------------------
# Epoch: 12/100
# Train_loss: 4282.0331 Train_Mae: 54.6272
# Test_loss: 3253.1937 Test_Mae: 48.3942
# --------------------------------
# Epoch: 13/100
# Train_loss: 3660.3468 Train_Mae: 50.4007
# Test_loss: 3224.7964 Test_Mae: 48.1156
# --------------------------------
# Epoch: 14/100
# Train_loss: 3770.8528 Train_Mae: 50.8699
# Test_loss: 3126.0197 Test_Mae: 47.0281
# --------------------------------
# Epoch: 15/100
# Train_loss: 3813.0896 Train_Mae: 50.9455
# Test_loss: 3045.9779 Test_Mae: 46.0222
# --------------------------------
# Epoch: 16/100
# Train_loss: 3469.0086 Train_Mae: 48.8481
# Test_loss: 2955.2139 Test_Mae: 44.9207
# --------------------------------
# Epoch: 17/100
# Train_loss: 3365.1297 Train_Mae: 47.8001
# Test_loss: 2957.5349 Test_Mae: 44.6942
# --------------------------------
# Epoch: 18/100
# Train_loss: 3622.6639 Train_Mae: 49.7990
# Test_loss: 2851.0065 Test_Mae: 43.6182
# --------------------------------
# Epoch: 19/100
# Train_loss: 3549.6930 Train_Mae: 48.7216
# Test_loss: 2893.9394 Test_Mae: 43.6085
# --------------------------------
# Epoch: 20/100
# Train_loss: 3286.3291 Train_Mae: 46.9861
# Test_loss: 2902.7386 Test_Mae: 43.3827
# --------------------------------
# Epoch: 21/100
# Train_loss: 3316.8281 Train_Mae: 46.9197
# Test_loss: 2837.7368 Test_Mae: 42.7424
# --------------------------------
# Epoch: 22/100
# Train_loss: 3217.0976 Train_Mae: 46.7337
# Test_loss: 2843.0038 Test_Mae: 42.6690
# --------------------------------
# Epoch: 23/100
# Train_loss: 3355.3392 Train_Mae: 47.4021
# Test_loss: 2740.4003 Test_Mae: 41.9321
# --------------------------------
# Epoch: 24/100
# Train_loss: 3310.0790 Train_Mae: 46.9939
# Test_loss: 2796.6940 Test_Mae: 42.0762
# --------------------------------
# Epoch: 25/100
# Train_loss: 3398.4635 Train_Mae: 47.2767
# Test_loss: 2745.9718 Test_Mae: 41.6003
# --------------------------------
# Epoch: 26/100
# Train_loss: 3045.9124 Train_Mae: 44.2874
# Test_loss: 2827.3134 Test_Mae: 42.1542
# --------------------------------
# Epoch: 27/100
# Train_loss: 3053.1101 Train_Mae: 44.7851
# Test_loss: 2758.9388 Test_Mae: 41.4905
# --------------------------------
# Epoch: 28/100
# Train_loss: 3045.0386 Train_Mae: 44.9338
# Test_loss: 2934.7836 Test_Mae: 42.8395
# --------------------------------
# Epoch: 29/100
# Train_loss: 3008.4324 Train_Mae: 44.6923
# Test_loss: 2734.3894 Test_Mae: 41.1415
# --------------------------------
# Epoch: 30/100
# Train_loss: 3140.6913 Train_Mae: 45.0154
# Test_loss: 2799.8990 Test_Mae: 41.6734
# --------------------------------
# Epoch: 31/100
# Train_loss: 3028.1644 Train_Mae: 44.4632
# Test_loss: 2861.5960 Test_Mae: 42.0781
# --------------------------------
# Epoch: 32/100
# Train_loss: 3263.0586 Train_Mae: 45.9878
# Test_loss: 2748.4664 Test_Mae: 41.0917
# --------------------------------
# Epoch: 33/100
# Train_loss: 3163.3533 Train_Mae: 45.4370
# Test_loss: 2913.3743 Test_Mae: 42.4313
# --------------------------------
# Epoch: 34/100
# Train_loss: 3119.7624 Train_Mae: 45.1534
# Test_loss: 2822.3945 Test_Mae: 41.6398
# --------------------------------
# Epoch: 35/100
# Train_loss: 3155.0085 Train_Mae: 46.0712
# Test_loss: 2754.1982 Test_Mae: 41.1104
# --------------------------------
# Epoch: 36/100
# Train_loss: 3156.3638 Train_Mae: 45.7974
# Test_loss: 2842.5571 Test_Mae: 41.7842
# --------------------------------
# Epoch: 37/100
# Train_loss: 3255.7961 Train_Mae: 45.7377
# Test_loss: 2768.4790 Test_Mae: 41.1011
# --------------------------------
# Epoch: 38/100
# Train_loss: 3116.3815 Train_Mae: 45.0687
# Test_loss: 2991.3468 Test_Mae: 42.8984
# --------------------------------
# Epoch: 39/100
# Train_loss: 3180.8382 Train_Mae: 45.1845
# Test_loss: 2773.0597 Test_Mae: 41.0681
# --------------------------------
# Epoch: 40/100
# Train_loss: 3113.4394 Train_Mae: 44.2200
# Test_loss: 2849.9582 Test_Mae: 41.7415
# --------------------------------
# Epoch: 41/100
# Train_loss: 3338.9948 Train_Mae: 47.1165
# Test_loss: 2846.0338 Test_Mae: 41.6852
# --------------------------------
# Epoch: 42/100
# Train_loss: 3045.5570 Train_Mae: 44.0979
# Test_loss: 2824.0000 Test_Mae: 41.4655
# --------------------------------
# Epoch: 43/100
# Train_loss: 3000.7179 Train_Mae: 44.2009
# Test_loss: 2943.9763 Test_Mae: 42.3589
# --------------------------------
# Epoch: 44/100
# Train_loss: 3023.1330 Train_Mae: 44.2380
# Test_loss: 2907.9783 Test_Mae: 41.9998
# --------------------------------
# Epoch: 45/100
# Train_loss: 2947.6198 Train_Mae: 43.6202
# Test_loss: 2885.3329 Test_Mae: 41.8471
# --------------------------------
# Epoch: 46/100
# Train_loss: 3018.7341 Train_Mae: 44.4039
# Test_loss: 2929.0491 Test_Mae: 42.2153
# --------------------------------
# Epoch: 47/100
# Train_loss: 3153.2021 Train_Mae: 45.1904
# Test_loss: 2898.2443 Test_Mae: 41.9860
# --------------------------------
# Epoch: 48/100
# Train_loss: 3011.2080 Train_Mae: 44.9581
# Test_loss: 2838.9347 Test_Mae: 41.5431
# --------------------------------
# Epoch: 49/100
# Train_loss: 2849.3836 Train_Mae: 42.4918
# Test_loss: 2926.8428 Test_Mae: 42.2097
# --------------------------------
# Epoch: 50/100
# Train_loss: 2990.0032 Train_Mae: 44.8957
# Test_loss: 2834.3863 Test_Mae: 41.5792
# --------------------------------
# Epoch: 51/100
# Train_loss: 3044.9489 Train_Mae: 45.0479
# Test_loss: 2883.9486 Test_Mae: 41.9465
# --------------------------------
# Epoch: 52/100
# Train_loss: 3044.9026 Train_Mae: 44.8147
# Test_loss: 3077.6777 Test_Mae: 43.2583
# --------------------------------
# Epoch: 53/100
# Train_loss: 3138.5823 Train_Mae: 45.3945
# Test_loss: 2846.3609 Test_Mae: 41.5498
# --------------------------------
# Epoch: 54/100
# Train_loss: 3014.3533 Train_Mae: 44.4442
# Test_loss: 2917.1124 Test_Mae: 42.0996
# --------------------------------
# Epoch: 55/100
# Train_loss: 2920.5494 Train_Mae: 43.1846
# Test_loss: 2889.2442 Test_Mae: 41.9208
# --------------------------------
# Epoch: 56/100
# Train_loss: 3097.4621 Train_Mae: 44.9282
# Test_loss: 2952.7280 Test_Mae: 42.3400
# --------------------------------
# Epoch: 57/100
# Train_loss: 3026.5668 Train_Mae: 44.1187
# Test_loss: 2853.1890 Test_Mae: 41.5642
# --------------------------------
# Epoch: 58/100
# Train_loss: 3257.7900 Train_Mae: 46.0297
# Test_loss: 2843.4625 Test_Mae: 41.4683
# --------------------------------
# Epoch: 59/100
# Train_loss: 2959.4524 Train_Mae: 43.5563
# Test_loss: 3066.9573 Test_Mae: 43.0794
# --------------------------------
# Epoch: 60/100
# Train_loss: 3234.5457 Train_Mae: 45.1306
# Test_loss: 2853.0703 Test_Mae: 41.5118
# --------------------------------
# Epoch: 61/100
# Train_loss: 2933.9700 Train_Mae: 43.6853
# Test_loss: 2884.0057 Test_Mae: 41.8139
# --------------------------------
# Epoch: 62/100
# Train_loss: 3090.2443 Train_Mae: 44.7974
# Test_loss: 3081.4315 Test_Mae: 43.1989
# --------------------------------
# Epoch: 63/100
# Train_loss: 3095.4630 Train_Mae: 44.7732
# Test_loss: 2868.5254 Test_Mae: 41.6552
# --------------------------------
# Epoch: 64/100
# Train_loss: 2929.4270 Train_Mae: 44.1802
# Test_loss: 3031.4103 Test_Mae: 42.9381
# --------------------------------
# Epoch: 65/100
# Train_loss: 3060.6962 Train_Mae: 43.9083
# Test_loss: 2862.3484 Test_Mae: 41.5777
# --------------------------------
# Epoch: 66/100
# Train_loss: 2894.4360 Train_Mae: 43.0168
# Test_loss: 3006.5045 Test_Mae: 42.7351
# --------------------------------
# Epoch: 67/100
# Train_loss: 3237.0014 Train_Mae: 46.4232
# Test_loss: 2896.9748 Test_Mae: 42.0134
# --------------------------------
# Epoch: 68/100
# Train_loss: 2992.9847 Train_Mae: 43.6972
# Test_loss: 2994.1638 Test_Mae: 42.5906
# --------------------------------
# Epoch: 69/100
# Train_loss: 2991.5212 Train_Mae: 43.4457
# Test_loss: 2921.0825 Test_Mae: 42.1354
# --------------------------------
# Epoch: 70/100
# Train_loss: 2950.4517 Train_Mae: 43.7671
# Test_loss: 2947.3689 Test_Mae: 42.3257
# --------------------------------
# Epoch: 71/100
# Train_loss: 2904.3042 Train_Mae: 43.5567
# Test_loss: 2973.7861 Test_Mae: 42.5178
# --------------------------------
# Epoch: 72/100
# Train_loss: 2817.2418 Train_Mae: 42.3451
# Test_loss: 2923.1329 Test_Mae: 42.1926
# --------------------------------
# Epoch: 73/100
# Train_loss: 3017.5161 Train_Mae: 43.5240
# Test_loss: 2917.2007 Test_Mae: 42.1518
# --------------------------------
# Epoch: 74/100
# Train_loss: 2919.6645 Train_Mae: 43.1756
# Test_loss: 2888.3722 Test_Mae: 41.9045
# --------------------------------
# Epoch: 75/100
# Train_loss: 2806.0067 Train_Mae: 42.8076
# Test_loss: 3022.1938 Test_Mae: 42.7797
# --------------------------------
# Epoch: 76/100
# Train_loss: 2932.6258 Train_Mae: 43.5900
# Test_loss: 2890.2276 Test_Mae: 41.8963
# --------------------------------
# Epoch: 77/100
# Train_loss: 3045.0432 Train_Mae: 44.3791
# Test_loss: 3033.9822 Test_Mae: 42.8423
# --------------------------------
# Epoch: 78/100
# Train_loss: 3018.4303 Train_Mae: 44.1379
# Test_loss: 2895.9661 Test_Mae: 42.0180
# --------------------------------
# Epoch: 79/100
# Train_loss: 2956.9319 Train_Mae: 43.7719
# Test_loss: 3014.3135 Test_Mae: 42.8625
# --------------------------------
# Epoch: 80/100
# Train_loss: 3117.0815 Train_Mae: 44.8606
# Test_loss: 2909.0015 Test_Mae: 42.1746
# --------------------------------
# Epoch: 81/100
# Train_loss: 2972.0949 Train_Mae: 43.5982
# Test_loss: 3111.4590 Test_Mae: 43.4043
# --------------------------------
# Epoch: 82/100
# Train_loss: 2996.9453 Train_Mae: 44.4622
# Test_loss: 2874.3450 Test_Mae: 41.9316
# --------------------------------
# Epoch: 83/100
# Train_loss: 3015.0969 Train_Mae: 43.8135
# Test_loss: 2981.5633 Test_Mae: 42.7236
# --------------------------------
# Epoch: 84/100
# Train_loss: 2857.7670 Train_Mae: 42.6740
# Test_loss: 2883.1020 Test_Mae: 41.9256
# --------------------------------
# Epoch: 85/100
# Train_loss: 2986.6364 Train_Mae: 43.4359
# Test_loss: 2967.2553 Test_Mae: 42.6244
# --------------------------------
# Epoch: 86/100
# Train_loss: 2893.9547 Train_Mae: 43.2332
# Test_loss: 2896.0529 Test_Mae: 42.1462
# --------------------------------
# Epoch: 87/100
# Train_loss: 2864.8968 Train_Mae: 42.3265
# Test_loss: 2952.5460 Test_Mae: 42.5762
# --------------------------------
# Epoch: 88/100
# Train_loss: 2892.3472 Train_Mae: 43.3167
# Test_loss: 2861.4917 Test_Mae: 41.6953
# --------------------------------
# Epoch: 89/100
# Train_loss: 2953.5606 Train_Mae: 43.2019
# Test_loss: 3163.9888 Test_Mae: 43.7756
# --------------------------------
# Epoch: 90/100
# Train_loss: 3000.3694 Train_Mae: 43.7104
# Test_loss: 2875.8193 Test_Mae: 42.0038
# --------------------------------
# Epoch: 91/100
# Train_loss: 2964.4683 Train_Mae: 43.0478
# Test_loss: 2936.9748 Test_Mae: 42.5306
# --------------------------------
# Epoch: 92/100
# Train_loss: 3079.5108 Train_Mae: 44.4979
# Test_loss: 3050.7375 Test_Mae: 43.1364
# --------------------------------
# Epoch: 93/100
# Train_loss: 3038.2087 Train_Mae: 44.0356
# Test_loss: 2868.6157 Test_Mae: 41.7627
# --------------------------------
# Epoch: 94/100
# Train_loss: 2972.5905 Train_Mae: 43.6523
# Test_loss: 3080.9260 Test_Mae: 43.2218
# --------------------------------
# Epoch: 95/100
# Train_loss: 3009.5738 Train_Mae: 44.6687
# Test_loss: 2860.3996 Test_Mae: 41.7145
# --------------------------------
# Epoch: 96/100
# Train_loss: 2844.7129 Train_Mae: 42.9532
# Test_loss: 3058.2296 Test_Mae: 43.1860
# --------------------------------
# Epoch: 97/100
# Train_loss: 2892.8336 Train_Mae: 43.2500
# Test_loss: 2877.1306 Test_Mae: 41.9927
# --------------------------------
# Epoch: 98/100
# Train_loss: 2894.3226 Train_Mae: 43.5145
# Test_loss: 3059.9094 Test_Mae: 43.1516
# --------------------------------
# Epoch: 99/100
# Train_loss: 2837.7280 Train_Mae: 42.9147
# Test_loss: 2906.3728 Test_Mae: 42.3038
# --------------------------------
# Epoch: 100/100
# Train_loss: 2914.3498 Train_Mae: 43.1343
# Test_loss: 3026.4965 Test_Mae: 43.0451

# %%
plt.figure()
plt.title("Train and Test Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.plot(range(1,epoch+1), train_loss_list, color="blue",
        linestyle="-", label="Train_Loss")
plt.plot(range(1,epoch+1),test_loss_list,color="red",
        linestyle="--", label="Test_Loss")
plt.legend()

plt.figure()
plt.title("Train and Test Mae")
plt.xlabel("Epoch")
plt.ylabel("Mae")
plt.plot(range(1,epoch+1), train_mae_list, color="blue",
        linestyle="-", label="Train_mae")
plt.plot(range(1,epoch+1),test_mae_list,color="red",
        linestyle="--", label="Test_Mae")
plt.legend()
